# %%
import torch
x = torch.randint(10,(2,30,256)); x.shape
# Out:
# torch.Size([2, 30, 256])

# %%
x.reshape(2,30, 8, 32)
# Out:
# tensor([[[[3, 7, 8,  ..., 3, 6, 7],
#           [0, 0, 9,  ..., 4, 1, 0],
#           [8, 5, 5,  ..., 6, 4, 8],
#           ...,
#           [3, 5, 9,  ..., 6, 7, 5],
#           [4, 1, 7,  ..., 4, 6, 0],
#           [1, 4, 4,  ..., 5, 0, 9]],
#
#          [[5, 0, 2,  ..., 6, 0, 8],
#           [0, 4, 3,  ..., 6, 9, 3],
#           [7, 9, 7,  ..., 9, 1, 0],
#           ...,
#           [2, 5, 0,  ..., 5, 0, 9],
#           [2, 3, 5,  ..., 0, 5, 9],
#           [2, 7, 9,  ..., 5, 2, 8]],
#
#          [[0, 0, 2,  ..., 1, 3, 2],
#           [7, 5, 9,  ..., 5, 1, 6],
#           [6, 6, 6,  ..., 0, 6, 0],
#           ...,
#           [9, 5, 5,  ..., 9, 5, 9],
#           [7, 6, 3,  ..., 7, 3, 9],
#           [9, 2, 6,  ..., 6, 8, 0]],
#
#          ...,
#
#          [[4, 9, 0,  ..., 7, 1, 2],
#           [8, 4, 2,  ..., 5, 0, 3],
#           [1, 2, 0,  ..., 9, 3, 5],
#           ...,
#           [9, 2, 6,  ..., 7, 0, 3],
#           [8, 9, 1,  ..., 9, 9, 6],
# ...

# %%
import numpy as np
a = np.arange(25).reshape(5,5)
b = np.arange(75).reshape(5,5,3)

# %%
c = a[...,None] + b

# %%
c[::2,[0,-1]]
# Out:
# array([[[ 0,  1,  2],
#         [16, 17, 18]],
#
#        [[40, 41, 42],
#         [56, 57, 58]],
#
#        [[80, 81, 82],
#         [96, 97, 98]]])
